# %% [markdown]
# # **Question No 01**
#
# About Pre-Processing
#
# Build the following dataset.
#
# Apply all the preprocessing steps
#
# Handle missing Price data by replacing Mean of Price
#
# *   Handle missing Quantity by replacing with 0
# *   Handle missing aftnoon and forenoon by replacing Mode of afternoon and forenoon respectively
# *   Handle missing bought by relacing the mean of exact same item.
# *   Replace Categorical values into numeric values
#
#
# ![Dataset2.png](data:image/png;base64,...)

# %%
#Solve Here

# %% [markdown]
# # **Question No 02**
#
# **Blog** => "Artificial Intelligence (AI) is rapidly transforming the job market, sparking both excitement and concern. While it's true that some repetitive and routine jobs may be automated, AI is also creating new opportunities in fields like data science, AI ethics, and human-centered roles that require creativity, empathy, and critical thinking. Rather than replacing humans entirely, AI is expected to augment our abilities, making work more efficient and allowing people to focus on more meaningful and strategic tasks. The future of work will belong to those who can adapt, learn new skills, and leverage technology to their advantage."
#
# *   Convert that blog into list of sentences.
# *   After getting list of sentences.
# *   Tokenize each sentence and apply all the preprocessing steps of NLP.

# %%
#Solve here

#1. List of sentences

#2. Tokenization

#3. lemmatization/stemming process

#4. remove stopwords and punctuation and convert it into lower case

# %% [markdown]
# # **Question No 03**
#
# A university is conducting a coding contest. Each student must register with their name, department, and the list of programming languages they know. The university wants to keep track of:
#
# All registered students and their details,
#
# Count of how many students know each programming language,
#
# Unique programming languages used,
#
# Departments involved.
#
# You are asked to write a Python program that helps manage this system.

# %%
#Solve here

# %% [markdown]
# # **Question No 04**
#
# You are developing a simple system to manage a library. The library has Books and Magazines. Both share common features like title, author, and publication_year, but they also have some unique properties:
#
# A Book has a genre and number_of_pages.
#
# A Magazine has an issue_number and month_of_issue.
#
# You are required to use inheritance to model this relationship.
#
#
# **Tasks:**
# Create a base class LibraryItem with attributes: title, author, and publication_year.
#
# Create a derived class Book that inherits from LibraryItem and adds genre and number_of_pages.
#
# Create another derived class Magazine that inherits from LibraryItem and adds issue_number and month_of_issue.
#
# Add a method display_info() in each class to print all details of the object.
#
# Create at least 2 objects of each class and call their display_info() methods to display their information.

# %%
#Solve here

# %% [markdown]
# # **Question No 05**
#
# You are building a patient management system for a hospital’s emergency room. Patients are treated based on the severity of their condition, represented by a priority number:
#
# The lower the number, the more severe the condition, and the sooner the patient should be treated.
#
# You are asked to implement a priority queue using a min-heap, where:
#
# A patient with priority 1 is treated before a patient with priority 5.
#
# The system should allow:
#
# Adding a new patient to the queue
#
# Viewing the next patient to treat
#
# Treating (removing) the next patient
#
#
# **Tasks:**
#
# Use Python’s heapq module to maintain the priority queue.
#
# Write a function add_patient(queue, priority, name) to insert a patient as a tuple (priority, name) into the heap.
#
# Write a function next_patient(queue) to view (peek) the patient with the highest priority.
#
# Write a function treat_patient(queue) to remove the patient who is being treated.
#
# Demonstrate the system with at least 5 patients, showing the treatment order.

# %%
#Solve here

# %% [markdown]
# # **Question No 06**
#
# 1. Read "cat_breeds_clean.csv" dataset.
# 2. Draw graphs of Weight vs categorical features.
# 3. set features to "Age_in_months","Body_length","Neutered_or_spayed","Owner_play_time_minutes" and label to "Weight".
# 4. split the dataset to 70:30 and 80:20.
# 5. Apply Linear Regression on both the split.
# 6. Do the prediction on the testing splits.
# 7. Evaluate your model.
# 8. Compare the results of both the split.
# 9. Store the evaluation resutls for botht the splits in the dictionary.

# %%
#Solve here

# %% [markdown]
# # **Question No 07**
#
# 1. Read "Titanic-Dataset.csv" dataset.
# 2. Display first 10 and last 10 rows from the above dataframe.
# 3. Display the information of the dataframe".
# 4. Display the summary of ALL columns.
# 5. Drop the columns 'PassengerId', 'Name', 'Ticket','Cabin'.
# 6. Fill the missing values of Age by its mean.
# 7. Set featurs and label to Survived.
# 8. Draw the count plot of Age.
# 9. Draw violinplot of Age Distribution vs Survival Status.
# 10. Draw the count plot of Passenger Class.
# 11. Draw th count plot of  Passenger Class on the basis Survival status.
# 12. split the dataset to 70:30 and 80:20.
# 13. Apply Random Forest Classifier on both the split.
# 14. Do the prediction on the testing splits.
# 15. Evaluate your model.
# 16. Compare the results of both the split.
# 17. Store the evaluation resutls for botht the splits in the dictionary.

# %%
#Solve here

# %% [markdown]
# # **Question No 08**
#
# 1. Read "penguins.csv.csv" dataset.
# 2. Display first 10 and last 10 rows from the above dataframe.
# 3. Display the information of the dataframe".
# 4. Display the summary of ALL columns.
# 5. Fill the missing values by its mean.
# 6. Draw the boxplot.
# 7. Convert catergorical values into numerical values.
# 8. Use Standard Scaler for the dataframe.
# 9. Set featurs.
# 10. Set k is from 1 to 10 and Detect the optimal number of clusters for k-means clustering. Set
# 11. Draw Scatter plot for clusters.
# 12. Store the clusters in the dataframe.

# %%
# Solve here

# %% [markdown]
# # **Question No 09**
#
# 1. from keras.datasets import fashion_mnist
# fashion_mnist.load_data()
# 2. Import Libraries
# 3. Split Dataset
# 4. Model creation
# 5. Layers Addition
# ```
# No. of epochs = 100
# Hidden unit = 100
# batch size = length of training input
# ```
# 6. Compilation
# 7. Fitting the model
# 8. Draw the Training and validation loss
# 9. Display the history for each epoch.

# %%
# Solve here
